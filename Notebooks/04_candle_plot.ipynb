# %% [markdown]
# ### Plot candles with plotly

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import pandas as pd
import utils
import plotly.graph_objects as go

# %%
pair = "EUR_USD"
granularity = "H1"

# %%
df = pd.read_pickle(utils.get_data_filename(pair, granularity, True))

# %%
df.describe()
# Out:
#              volume
# count   4000.000000
# mean    3119.955500
# std     2324.660741
# min       95.000000
# 25%     1556.500000
# 50%     2568.000000
# 75%     3996.750000
# max    21489.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    4000 non-null   object
#  1   volume  4000 non-null   int64
#  2   mid_o   4000 non-null   object
#  3   mid_h   4000 non-null   object
#  4   mid_l   4000 non-null   object
#  5   mid_c   4000 non-null   object
#  6   bid_o   4000 non-null   object
#  7   bid_h   4000 non-null   object
#  8   bid_l   4000 non-null   object
#  9   bid_c   4000 non-null   object
#  10  ask_o   4000 non-null   object
#  11  ask_h   4000 non-null   object
#  12  ask_l   4000 non-null   object
#  13  ask_c   4000 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 437.6+ KB

# %%
non_cols = ['time', 'volume']

# %%
mod_cols = [x for x in df.columns if x not in non_cols]

# %%
mod_cols
# Out:
# ['mid_o',
#  'mid_h',
#  'mid_l',
#  'mid_c',
#  'bid_o',
#  'bid_h',
#  'bid_l',
#  'bid_c',
#  'ask_o',
#  'ask_h',
#  'ask_l',
#  'ask_c']

# %%
df[mod_cols] = df[mod_cols].apply(pd.to_numeric)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    4000 non-null   object
#  1   volume  4000 non-null   int64
#  2   mid_o   4000 non-null   float64
#  3   mid_h   4000 non-null   float64
#  4   mid_l   4000 non-null   float64
#  5   mid_c   4000 non-null   float64
#  6   bid_o   4000 non-null   float64
#  7   bid_h   4000 non-null   float64
#  8   bid_l   4000 non-null   float64
#  9   bid_c   4000 non-null   float64
#  10  ask_o   4000 non-null   float64
#  11  ask_h   4000 non-null   float64
#  12  ask_l   4000 non-null   float64
#  13  ask_c   4000 non-null   float64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 437.6+ KB

# %%
df.describe()
# Out:
#              volume        mid_o        mid_h        mid_l        mid_c  \
# count   4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean    3119.955500     1.082934     1.083429     1.082436     1.082934
# std     2324.660741     0.009110     0.009120     0.009090     0.009110
# min       95.000000     1.061000     1.061260     1.060110     1.061010
# 25%     1556.500000     1.076577     1.077000     1.076120     1.076580
# 50%     2568.000000     1.083435     1.083905     1.082930     1.083425
# 75%     3996.750000     1.088700     1.089120     1.088260     1.088720
# max    21489.000000     1.112920     1.113960     1.112270     1.112940
#
#              bid_o        bid_h        bid_l        bid_c        ask_o  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean      1.082850     1.083351     1.082352     1.082855     1.083017
# std       0.009109     0.009119     0.009088     0.009109     0.009111
# min       1.060920     1.061190     1.060040     1.060940     1.061070
# 25%       1.076500     1.076920     1.076040     1.076507     1.076665
# 50%       1.083345     1.083835     1.082850     1.083350     1.083515
# 75%       1.088630     1.089043     1.088163     1.088640     1.088782
# max       1.112840     1.113880     1.112190     1.112860     1.112990
#
#              ask_h        ask_l        ask_c
# count  4000.000000  4000.000000  4000.000000
# mean      1.083511     1.082515     1.083013
# std       0.009122     0.009091     0.009111
# min       1.061330     1.060180     1.061080
# 25%       1.077093     1.076190     1.076658
# 50%       1.084000     1.083010     1.083500
# 75%       1.089190     1.088332     1.088790
# max       1.114040     1.112350     1.113020

# %%
df_plot = df.iloc[-100:].copy()

# %%
df_plot
# Out:
#                                 time  volume    mid_o    mid_h    mid_l  \
# 3900  2024-08-05T17:00:00.000000000Z   10896  1.09598  1.09645  1.09473
# 3901  2024-08-05T18:00:00.000000000Z    7454  1.09534  1.09576  1.09490
# 3902  2024-08-05T19:00:00.000000000Z    6127  1.09510  1.09589  1.09496
# 3903  2024-08-05T20:00:00.000000000Z    2484  1.09592  1.09602  1.09494
# 3904  2024-08-05T21:00:00.000000000Z     388  1.09492  1.09547  1.09492
# ...                              ...     ...      ...      ...      ...
# 3995  2024-08-09T16:00:00.000000000Z    4477  1.09241  1.09247  1.09178
# 3996  2024-08-09T17:00:00.000000000Z    3940  1.09188  1.09236  1.09152
# 3997  2024-08-09T18:00:00.000000000Z    4443  1.09208  1.09218  1.09172
# 3998  2024-08-09T19:00:00.000000000Z    2500  1.09195  1.09213  1.09172
# 3999  2024-08-09T20:00:00.000000000Z    1031  1.09188  1.09194  1.09146
#
#         mid_c    bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l  \
# 3900  1.09534  1.09591  1.09637  1.09466  1.09526  1.09605  1.09653  1.09480
# 3901  1.09511  1.09526  1.09568  1.09483  1.09504  1.09541  1.09583  1.09498
# 3902  1.09589  1.09503  1.09581  1.09488  1.09581  1.09518  1.09597  1.09503
# 3903  1.09514  1.09583  1.09595  1.09485  1.09506  1.09600  1.09611  1.09502
# 3904  1.09543  1.09472  1.09530  1.09472  1.09522  1.09513  1.09565  1.09511
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 3995  1.09187  1.09233  1.09239  1.09170  1.09180  1.09249  1.09255  1.09186
# 3996  1.09208  1.09181  1.09228  1.09145  1.09200  1.09196  1.09244  1.09160
# 3997  1.09196  1.09200  1.09211  1.09164  1.09189  1.09216  1.09226  1.09180
# 3998  1.09187  1.09188  1.09205  1.09164  1.09179  1.09202  1.09221  1.09179
# 3999  1.09156  1.09181  1.09187  1.09139  1.09146  1.09196  1.09202  1.09154
#
#         ask_c
# 3900  1.09542
# 3901  1.09518
# 3902  1.09597
# 3903  1.09522
# 3904  1.09564
# ...       ...
# 3995  1.09194
# 3996  1.09215
# 3997  1.09204
# 3998  1.09195
# 3999  1.09165
#
# [100 rows x 14 columns]

# %%
df_plot.shape
# Out:
# (100, 14)

# %%
fig = go.Figure()
fig.add_trace(go.Candlestick(
    x=df_plot.time, open=df_plot.mid_o, high=df_plot.mid_h, low=df_plot.mid_l, close=df_plot.mid_c,
    line=dict(width=1), opacity=1,
    increasing_fillcolor='#24A06B',
    decreasing_fillcolor="#CC2E3C",
    increasing_line_color='#2EC886',  
    decreasing_line_color='#FF3A4C'
))
fig.update_layout(width=1200,height=600,
    margin=dict(l=10,r=10,b=10,t=10),
    font=dict(size=10,color="#e1e1e1"),
    paper_bgcolor="#1e1e1e",
    plot_bgcolor="#1e1e1e")
fig.update_xaxes(
    gridcolor="#1f292f",
    showgrid=True,fixedrange=True,rangeslider=dict(visible=True)
)
fig.update_yaxes(
    gridcolor="#1f292f",
    showgrid=True
)
fig.show()
