# %% [markdown]
# ### Get currency instruments from file
# - currency_instruments.pkl

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'Oanda')))

from instrument import Instrument
import pandas as pd

# %%
print(Instrument.get_currency_instruments_list(True))
# Out:
# [{'name': 'USD_CNH', 'ins_type': 'CURRENCY', 'displayName': 'USD/CNH', 'pipLocation': 0.0001, 'marginRate': '0.05'}, {'name': 'NZD_CAD', 'ins_type': 'CURRENCY', 'displayName': 'NZD/CAD', 'pipLocation': 0.0001, 'marginRate': '0.05'}, {'name': 'EUR_CHF', 'ins_type': 'CURRENCY', 'displayName': 'EUR/CHF', 'pipLocation': 0.0001, 'marginRate': '0.04'}, {'name': 'SGD_CHF', 'ins_type': 'CURRENCY', 'displayName': 'SGD/CHF', 'pipLocation': 0.0001, 'marginRate': '0.05'}, {'name': 'EUR_CZK', 'ins_type': 'CURRENCY', 'displayName': 'EUR/CZK', 'pipLocation': 0.0001, 'marginRate': '0.05'}, {'name': 'NZD_JPY', 'ins_type': 'CURRENCY', 'displayName': 'NZD/JPY', 'pipLocation': 0.01, 'marginRate': '0.05'}, {'name': 'CHF_HKD', 'ins_type': 'CURRENCY', 'displayName': 'CHF/HKD', 'pipLocation': 0.0001, 'marginRate': '0.1'}, {'name': 'EUR_GBP', 'ins_type': 'CURRENCY', 'displayName': 'EUR/GBP', 'pipLocation': 0.0001, 'marginRate': '0.0333'}, {'name': 'EUR_NOK', 'ins_type': 'CURRENCY', 'displayName': 'EUR/NOK', 
# ...

# %%
print(Instrument.get_instruments_list(True))
# Out:
# [{'name': 'USD_CNH', 'ins_type': 'CURRENCY', 'displayName': 'USD/CNH', 'pipLocation': 0.0001, 'marginRate': '0.05'}, {'name': 'NZD_CAD', 'ins_type': 'CURRENCY', 'displayName': 'NZD/CAD', 'pipLocation': 0.0001, 'marginRate': '0.05'}, {'name': 'EUR_CHF', 'ins_type': 'CURRENCY', 'displayName': 'EUR/CHF', 'pipLocation': 0.0001, 'marginRate': '0.04'}, {'name': 'SGD_CHF', 'ins_type': 'CURRENCY', 'displayName': 'SGD/CHF', 'pipLocation': 0.0001, 'marginRate': '0.05'}, {'name': 'XAU_AUD', 'ins_type': 'METAL', 'displayName': 'Gold/AUD', 'pipLocation': 0.01, 'marginRate': '0.05'}, {'name': 'WHEAT_USD', 'ins_type': 'CFD', 'displayName': 'Wheat', 'pipLocation': 0.01, 'marginRate': '0.10'}, {'name': 'EUR_CZK', 'ins_type': 'CURRENCY', 'displayName': 'EUR/CZK', 'pipLocation': 0.0001, 'marginRate': '0.05'}, {'name': 'XAG_USD', 'ins_type': 'METAL', 'displayName': 'Silver', 'pipLocation': 0.0001, 'marginRate': '0.10'}, {'name': 'NZD_JPY', 'ins_type': 'CURRENCY', 'displayName': 'NZD/JPY', 'pipLocation':
# ...

# %%
currency_list = Instrument.get_currency_instruments_list(True)

for currency in currency_list:
    print(currency)
# Out:
# {'name': 'USD_CNH', 'ins_type': 'CURRENCY', 'displayName': 'USD/CNH', 'pipLocation': 0.0001, 'marginRate': '0.05'}
# {'name': 'NZD_CAD', 'ins_type': 'CURRENCY', 'displayName': 'NZD/CAD', 'pipLocation': 0.0001, 'marginRate': '0.05'}
# {'name': 'EUR_CHF', 'ins_type': 'CURRENCY', 'displayName': 'EUR/CHF', 'pipLocation': 0.0001, 'marginRate': '0.04'}
# {'name': 'SGD_CHF', 'ins_type': 'CURRENCY', 'displayName': 'SGD/CHF', 'pipLocation': 0.0001, 'marginRate': '0.05'}
# {'name': 'EUR_CZK', 'ins_type': 'CURRENCY', 'displayName': 'EUR/CZK', 'pipLocation': 0.0001, 'marginRate': '0.05'}
# {'name': 'NZD_JPY', 'ins_type': 'CURRENCY', 'displayName': 'NZD/JPY', 'pipLocation': 0.01, 'marginRate': '0.05'}
# {'name': 'CHF_HKD', 'ins_type': 'CURRENCY', 'displayName': 'CHF/HKD', 'pipLocation': 0.0001, 'marginRate': '0.1'}
# {'name': 'EUR_GBP', 'ins_type': 'CURRENCY', 'displayName': 'EUR/GBP', 'pipLocation': 0.0001, 'marginRate': '0.0333'}
# ...

# %%
instrument_list = Instrument.get_instruments_list(True)
for instrument in instrument_list:
    print(instrument)
# Out:
# {'name': 'USD_CNH', 'ins_type': 'CURRENCY', 'displayName': 'USD/CNH', 'pipLocation': 0.0001, 'marginRate': '0.05'}
# {'name': 'NZD_CAD', 'ins_type': 'CURRENCY', 'displayName': 'NZD/CAD', 'pipLocation': 0.0001, 'marginRate': '0.05'}
# {'name': 'EUR_CHF', 'ins_type': 'CURRENCY', 'displayName': 'EUR/CHF', 'pipLocation': 0.0001, 'marginRate': '0.04'}
# {'name': 'SGD_CHF', 'ins_type': 'CURRENCY', 'displayName': 'SGD/CHF', 'pipLocation': 0.0001, 'marginRate': '0.05'}
# {'name': 'XAU_AUD', 'ins_type': 'METAL', 'displayName': 'Gold/AUD', 'pipLocation': 0.01, 'marginRate': '0.05'}
# {'name': 'WHEAT_USD', 'ins_type': 'CFD', 'displayName': 'Wheat', 'pipLocation': 0.01, 'marginRate': '0.10'}
# {'name': 'EUR_CZK', 'ins_type': 'CURRENCY', 'displayName': 'EUR/CZK', 'pipLocation': 0.0001, 'marginRate': '0.05'}
# {'name': 'XAG_USD', 'ins_type': 'METAL', 'displayName': 'Silver', 'pipLocation': 0.0001, 'marginRate': '0.10'}
# ...
